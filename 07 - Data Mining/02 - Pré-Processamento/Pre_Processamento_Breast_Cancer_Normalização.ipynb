# %% [markdown]
# # Pré-processamento - Roteiro da aula:
#
# ## 1 -  Limpeza de Dados
# ### (i) Pandas
#
# * Removendo Dados Duplicados: \\
# Um conjunto de dados pode conter linhas repetidas. \\
# O Pandas oferece o método .drop_duplicates() para remover
# essas duplicatas.
# * Tratando Valores Ausentes: \\
# Dados incompletos (NaN) afetam as análises. \\
# O Pandas oferece os métodos .fillna() e .dropna()
# para lidar com valores ausentes. \\
#
# ### (ii) Usando a Classe SimpleImputer
# * A classe SimpleImputer pertence ao pacote sklearn.impute.
#
# ## 2 - Normalização dos Dados
#
# Por reescala: define através de um valor mínimo e um valor máximo, um novo intervalo \\
# onde os valores de um atributo estarão contidos (Exemplo: [0, 1]). \\
# A normalização por reescala de um atributo $j$ de um objeto $x_i$ pode ser calculada como: \\
#
# $$ x_{ij} = \frac{x_{ij} - min_j}{max_j - min_j} $$
#
#
# Por padronização: os diferentes atributos contínuos poderão abranger diferentes intervalos, \\
# mas deverão possuir os mesmos valores para alguma medida de posição e de espalhamento. \\
# Essas medidas irão consistir na média e no desvio-padrão. \\
#
# $$ x_{ij} = \frac{x_{ij} - \bar{x}_j}{\sigma_j} $$

# %% [markdown]
# ## Estudo de Caso:
# ### Breast Cancer dataset
#
# * https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Leitura da Base de Dados

# %%
# Faz a leitura da base de dados
def readDataset(dataset):
    return pd.read_csv(dataset)

# %% [markdown]
# ### Limpeza dos Dados

# %% [markdown]
# #### Remoção de amostras NaN

# %%
def removeSamples(dataframe, feature):
  dataframe.dropna(subset=[feature], inplace=True)

# %% [markdown]
# #### Tratamento dos dados faltantes nas demais colunas

# %%
def fillSamples(dataframe):
  nan_columns = dataframe.columns[dataframe.isna().any()].tolist()
  for col in nan_columns:
    dataframe[col].fillna(dataframe[col].mean(), inplace=True)

# %% [markdown]
# #### Normalização de atributos numéricos
# * StandardScaler e MinMaxScaler

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
def stdScaler(dataframe, columns):
  scaler = StandardScaler()
  dataframe[columns] = scaler.fit_transform(dataframe[columns])

# %%
def minMax(dataframe, columns):
  scaler = MinMaxScaler()
  dataframe[columns] = scaler.fit_transform(dataframe[columns])

# %% [markdown]
# ### Testando padronização StandardScaler

# %%
# Carrega a base de dados
df = readDataset('breast_cancer_missing.csv')

# %%
# Remove as amostras com diagnosis igual NaN
removeSamples(df, 'diagnosis')

# %%
# Armazena o nome das colunas com dados faltantes
nan_columns = df.columns[df.isna().any()].tolist()

# %%
# Substitui os dados faltantes pela média
fillSamples(df)

# %%
# Aplica a padronização StandarScaler nas colunas com dados faltantes
stdScaler(df, nan_columns)

# %%
# Verifica o resultado das 5 primeiras linhas
df.head()
# Out:
#    sample_id  mean_radius  mean_texture  mean_perimeter     mean_area  \
# 0     842302     1.085817     -2.172329        1.283164  3.421260e-16
# 2   84300903     1.572820      0.481953        1.591406  1.646896e+00
# 3   84348301    -0.796309      0.269513       -0.652770 -8.114597e-01
# 4   84358402     1.744704     -1.205359        1.809745  1.929777e+00
# 5     843786    -0.501242     -0.873269       -0.439141 -5.376068e-01
#
#    mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# 0         1.622464      3.508049e+00    2.736543e+00             2.562904
# 2         0.968696      2.809158e-16    3.625689e-16             2.055453
# 3         3.412898      3.635574e+00    3.625689e-16             1.455497
# 4         0.277781      5.769897e-01    3.625689e-16             1.431710
# 5         2.320808      1.329997e+00    8.776898e-01             0.812990
#
#    mean_symmetry  ...  worst_texture  worst_perimeter  worst_area  \
# 0   1.054117e-15  ...      -1.484189         2.356961    2.106997
# 2   9.665091e-01  ...      -0.007520         1.374195    1.533224
# 3   2.971777e+00  ...       0.167159        -0.267728   -0.579187
# 4  -2.093352e-02  ...      -1.603042         1.365011    1.285206
# 5   1.034871e+00  ...      -0.328065        -0.129039   -0.257318
#
#    worst_smoothness  worst_compactness  worst_concavity  worst_concave_points  \
# 0          1.462564           2.759463         0.000000              2.375010
# 2          0.597244           1.143226         0.886155              2.020424
# 3          3.776567           4.104876         2.073151              2.249955
# 4          0.256950          -0.328214         0.633198              0.746131
# 5          2.284133           1.816267         1.313273              0.929756
#
#    worst_symmetry  worst_fractal_dimension  diagnosis
# 0        2.859841                 2.124614  malignant
# 2        0.000000                 0.210300  malignant
# 3        6.292452                 5.431268  malignant
# 4       -0.909796                -0.449808  malignant
# 5        1.821801                 2.460780  malignant
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Testando normalização MinMaxScaler

# %%
# Carrega a base de dados
df = readDataset('breast_cancer_missing.csv')

# %%
# Remove as amostras com diagnosis igual NaN
removeSamples(df, 'diagnosis')

# %%
# Armazena o nome das colunas com dados faltantes
nan_columns = df.columns[df.isna().any()].tolist()

# %%
# Substitui os dados faltantes pela média
fillSamples(df)

# %%
# Aplica a normalização MinMaxScaler nas colunas com dados faltantes
minMax(df, nan_columns)

# %%
# Verifica o resultado das 5 primeiras linhas
df.head()
# Out:
#    sample_id  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 0     842302     0.521037      0.022658        0.552093   0.217283
# 2   84300903     0.601496      0.390260        0.602404   0.449417
# 3   84348301     0.210090      0.360839        0.236112   0.102906
# 4   84358402     0.629893      0.156578        0.638041   0.489290
# 5     843786     0.258839      0.202570        0.270980   0.141506
#
#    mean_smoothness  mean_compactness  mean_concavity  mean_concave_points  \
# 0         0.553970          0.792037        0.703140             0.731113
# 2         0.466746          0.260461        0.212302             0.635686
# 3         0.792844          0.811361        0.212302             0.522863
# 4         0.374566          0.347893        0.212302             0.518390
# 5         0.647140          0.461996        0.369728             0.402038
#
#    mean_symmetry  ...  worst_texture  worst_perimeter  worst_area  \
# 0       0.381067  ...       0.159030         0.668310    0.450698
# 2       0.509596  ...       0.404612         0.508442    0.374508
# 3       0.776263  ...       0.433663         0.241347    0.094008
# 4       0.378283  ...       0.139263         0.506948    0.341575
# 5       0.518687  ...       0.351303         0.263908    0.136748
#
#    worst_smoothness  worst_compactness  worst_concavity  worst_concave_points  \
# 0          0.656640           0.619292         0.218722              0.912027
# 2          0.528241           0.385375         0.359744              0.835052
# 3          1.000000           0.814012         0.548642              0.884880
# 4          0.477747           0.172415         0.319489              0.558419
# 5          0.778547           0.482784         0.427716              0.598282
#
#    worst_symmetry  worst_fractal_dimension  diagnosis
# 0        0.598462                 0.541370  malignant
# 2        0.263926                 0.275856  malignant
# 3        1.000000                 1.000000  malignant
# 4        0.157500                 0.184300  malignant
# 5        0.477035                 0.587996  malignant
#
# [5 rows x 32 columns]
